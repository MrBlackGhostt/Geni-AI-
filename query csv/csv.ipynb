# %%
import pandas as pd
import panel as pn

# %%
file_name = "./data.csv"
data = pd.read_csv(file_name).drop(columns=['id'])

# %%
#Create plotly pane for interactive plotting
pn.pane.Plotly(sizing_mode="stretch_width")
# Out:
# Plotly(None, sizing_mode='stretch_width')

# %%
#initialize a FileInput widget for the uploading the file
file_input = pn.widgets.FileInput()

# %%
text_input = pn.widgets.TextInput(name="Question", 
                                  placeholder='Ask a question from the CSV',
                                  sizing_mode='scale_width')
# Initialize a TextInput widget for user questions

# %%
#Initialize the button widget for submiting the response
ask_button = pn.widgets.Button(
    name="Ask",
    button_type = "primary",
    height=60
)
